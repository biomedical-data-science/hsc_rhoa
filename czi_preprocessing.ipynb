# %%
import os
from glob import glob

#loads necessary code functions from hsc_spatial_stats.py
#all documentation for algorithms are found in the python code
from hsc_spatial_stats import *

# Turn interactive plotting off
plt.ioff()

# %%
## Choose the new resolution and normalization for CZI preprocessing
RESOLUTION = 0.05
normalization = "none"

# Biological conditions of HSC to consider
conditions = ['old', 'treated_RhoAi', 'treated_NaB', 'compressed_8um',
             'compressed_3um', 'RhoA_KO', 'young', 'compressed_5um']

#containing folder with .czi images inside
outliers = pd.read_csv("hsc_raw_data/czi_image_outliers.csv")['path'].values
input_dir = 'hsc_raw_data'
output_dir = f'segmented_nucleus/res_{RESOLUTION}_{normalization}_norm'

hist_df = pd.DataFrame()

# Create output directory if it does not exist already
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for cond in conditions:
    # Create condition folder if it does not exist already    
    output_dir = f'segmented_nucleus/res_{RESOLUTION}_{normalization}_norm/{cond}'
    if not os.path.exists(output_dir):
            os.makedirs(output_dir)

    img_list = glob(f'{input_dir}/{cond}/**/*.czi', recursive=True)

    # For each image within this condition
    for i, img_path in enumerate(img_list, 1):

        out_path = get_output_filename_with_subfolder(
            img_path, output_dir, suffix='XY')

        # If this cell was already processed - skip
        if os.path.exists(out_path):
            continue

        # skip outliers
        if img_path in outliers:
            print('Outlier identified - skipping')
            continue

        # Log information to the user
        print(img_path)
        print("Image Number : "+ str(i))
        
        #DAPI signal usually is named "Ch1-T3" 
        img, nuc_mask = czi_image_preprocessing(
            img_path, output_dir, channel_name='Ch1-T3', new_res=RESOLUTION, 
            resize=True, normalization=normalization)

        if img=='':
        #if missing then search for "Ch1-T2" channel
            img, nuc_mask = czi_image_preprocessing(
                img_path, output_dir, channel_name='Ch1-T2', new_res=RESOLUTION, 
                resize=True, normalization=normalization)
                
            if img=='':
                continue
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 10
#       6 conditions = ['old', 'treated_RhoAi', 'treated_NaB', 'compressed_8um',
#       7              'compressed_3um', 'RhoA_KO', 'young', 'compressed_5um']
#       9 #containing folder with .czi images inside
# ---> 10 outliers = pd.read_csv("data/raw_data/czi_image_outliers.csv")['path'].values
#      11 input_dir = 'data/raw_data'
#      12 output_dir = f'segmented_nucleus/res_{RESOLUTION}_{normalization}_norm'
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/miniconda3/envs/hsc/lib/python3.11/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw_data/czi_image_outliers.csv'

# %%
## Choose the new resolution and normalization for CZI preprocessing
RESOLUTION = 0.1
normalization = "z_score"

# Biological conditions of HSC to consider
conditions = ['old', 'treated_RhoAi', 'treated_NaB', 'compressed_8um',
             'compressed_3um', 'RhoA_KO', 'young', 'compressed_5um']

#containing folder with .czi images inside
outliers = pd.read_csv("hsc_raw_data/czi_image_outliers.csv")['path'].values
input_dir = 'hsc_raw_data'
output_dir = f'segmented_nucleus/res_{RESOLUTION}_{normalization}_norm'

hist_df = pd.DataFrame()

# Create output directory if it does not exist already
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for cond in conditions:
    # Create condition folder if it does not exist already    
    output_dir = f'segmented_nucleus/res_{RESOLUTION}_{normalization}_norm/{cond}'
    if not os.path.exists(output_dir):
            os.makedirs(output_dir)

    img_list = glob(f'{input_dir}/{cond}/**/*.czi', recursive=True)

    # For each image within this condition
    for i, img_path in enumerate(img_list, 1):

        out_path = get_output_filename_with_subfolder(
            img_path, output_dir, suffix='XY')

        # If this cell was already processed - skip
        if os.path.exists(out_path):
            continue

        # skip outliers
        if img_path in outliers:
            print('Outlier identified - skipping')
            continue

        # Log information to the user
        print(img_path)
        print("Image Number : "+ str(i))
        
        #DAPI signal usually is named "Ch1-T3" 
        img, nuc_mask = czi_image_preprocessing(
            img_path, output_dir, channel_name='Ch1-T3', new_res=RESOLUTION, 
            resize=True, normalization=normalization)

        if img=='':
        #if missing then search for "Ch1-T2" channel
            img, nuc_mask = czi_image_preprocessing(
                img_path, output_dir, channel_name='Ch1-T2', new_res=RESOLUTION, 
                resize=True, normalization=normalization)
                
            if img=='':
                continue
# Out:
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 49.czi
# Image Number : 57
# Rescaling image. New Image Size:  (103, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (89, 69, 70)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 41.czi
# Image Number : 58
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (76, 63, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 43.czi
# Image Number : 59
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (78, 73, 76)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 44.czi
# Image Number : 60
# Rescaling image. New Image Size:  (85, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (68, 74, 68)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 48.czi
# Image Number : 61
# Rescaling image. New Image Size:  (81, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (70, 76, 71)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 47.czi
# Image Number : 62
# Rescaling image. New Image Size:  (81, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (71, 72, 68)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 50.czi
# Image Number : 63
# Rescaling image. New Image Size:  (103, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (88, 64, 74)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 51.czi
# Image Number : 64
# Rescaling image. New Image Size:  (96, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (84, 70, 66)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 40.czi
# Image Number : 65
# Rescaling image. New Image Size:  (81, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (67, 72, 82)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 45.czi
# Image Number : 66
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (70, 76, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 42.czi
# Image Number : 67
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (76, 75, 71)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230119exp_20230127_AgRhoA647PPL2A/Image 46.czi
# Image Number : 68
# Rescaling image. New Image Size:  (81, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (79, 79, 68)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230321Ag_KLF4cy3/Image 32.czi
# Image Number : 69
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (87, 74, 72)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230321Ag_KLF4cy3/Image 34.czi
# Image Number : 70
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (89, 74, 75)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230321Ag_KLF4cy3/Image 31.czi
# Image Number : 71
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (75, 78, 81)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230321Ag_KLF4cy3/Image 35.czi
# Image Number : 72
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (82, 63, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230322_agRGPPLA2/Image 39.czi
# Image Number : 73
# Rescaling image. New Image Size:  (64, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (55, 79, 80)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230322_agRGPPLA2/Image 40.czi
# Image Number : 74
# Rescaling image. New Image Size:  (80, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (75, 69, 92)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230323_agRGPPLA2/Image 5.czi
# Image Number : 75
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (81, 80, 80)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230323_agRGPPLA2/Image 9.czi
# Image Number : 76
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (84, 83, 72)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230323_agRGPPLA2/Image 8.czi
# Image Number : 77
# Rescaling image. New Image Size:  (99, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (82, 77, 74)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230323_agRGPPLA2/Image 7.czi
# Image Number : 78
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (78, 75, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230323_agRGPPLA2/Image 11.czi
# Image Number : 79
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (83, 69, 75)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230323_agRGPPLA2/Image 10.czi
# Image Number : 80
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (82, 71, 79)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230315Ag_KLF4cy3/Image 11.czi
# Image Number : 81
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (89, 66, 71)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230315Ag_KLF4cy3/Image 13.czi
# Image Number : 82
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (99, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (105, 79, 70)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230315Ag_KLF4cy3/Image 10.czi
# Image Number : 83
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (85, 71, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230315Ag_KLF4cy3/Image 12.czi
# Image Number : 84
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (92, 75, 70)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230322Ag_KLF4cy3/Image 11.czi
# Image Number : 85
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (85, 68, 83)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230322Ag_KLF4cy3/Image 10.czi
# Image Number : 86
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (83, 76, 80)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/old/wetransfer_28032023/20230208exp_20230322Ag_KLF4cy3/Image 12.czi
# Image Number : 87
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (80, 73, 73)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 18.czi
# Image Number : 24
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (86, 78, 72)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 14.czi
# Image Number : 25
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (77, 74, 80)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 16.czi
# Image Number : 26
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (74, 71, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 15.czi
# Image Number : 27
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (80, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (79, 85, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 17.czi
# Image Number : 28
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (91, 74, 85)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 21.czi
# Image Number : 29
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (80, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (80, 79, 84)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 20.czi
# Image Number : 30
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (95, 75, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230321agRi_KLF4cy3/Image 19.czi
# Image Number : 31
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (82, 76, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230315agRi_KLF4cy3/Image 5.czi
# Image Number : 32
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (86, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (85, 68, 79)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230315agRi_KLF4cy3/Image 6.czi
# Image Number : 33
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (80, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (86, 75, 79)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230315agRi_KLF4cy3/Image 3.czi
# Image Number : 34
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (88, 68, 80)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230315agRi_KLF4cy3/Image 1.czi
# Image Number : 35
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (79, 81, 81)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230315agRi_KLF4cy3/Image 4.czi
# Image Number : 36
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (92, 81, 74)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230315agRi_KLF4cy3/Image 2.czi
# Image Number : 37
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (85, 76, 84)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230322agRi_KLF4cy3/Image 18.czi
# Image Number : 38
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (83, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (75, 71, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230322agRi_KLF4cy3/Image 16.czi
# Image Number : 39
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (70, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (76, 74, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230208exp_20230322agRi_KLF4cy3/Image 17.czi
# Image Number : 40
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (80, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (81, 69, 74)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230119exp_20230127_AgRiRhoA647PPL2A/Image 53.czi
# Image Number : 41
# Rescaling image. New Image Size:  (85, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (76, 65, 79)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230119exp_20230127_AgRiRhoA647PPL2A/Image 57.czi
# Image Number : 42
# Rescaling image. New Image Size:  (85, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (74, 62, 69)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/treated_RhoAi/wetransfer_28032023/20230119exp_20230127_AgRiRhoA647PPL2A/Image 58.czi
# Image Number : 43
# Rescaling image. New Image Size:  (92, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (78, 69, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# ...
#   if img == '':
# (72, 57, 81)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 34.czi
# Image Number : 51
# Rescaling image. New Image Size:  (85, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (85, 63, 70)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 36.czi
# Image Number : 52
# Rescaling image. New Image Size:  (81, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (74, 76, 72)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 30.czi
# Image Number : 53
# Rescaling image. New Image Size:  (70, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (69, 73, 62)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 39.czi
# Image Number : 54
# Rescaling image. New Image Size:  (81, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (74, 129, 108)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 29.czi
# Image Number : 55
# Rescaling image. New Image Size:  (70, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (62, 68, 78)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 31.czi
# Image Number : 56
# Rescaling image. New Image Size:  (70, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (67, 82, 72)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 33.czi
# Image Number : 57
# Rescaling image. New Image Size:  (77, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (68, 73, 63)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 38.czi
# Image Number : 58
# Rescaling image. New Image Size:  (77, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (73, 78, 74)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 28.czi
# Image Number : 59
# Rescaling image. New Image Size:  (74, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (64, 65, 68)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230119exp_20230127_YoungRhoA647PPL2A/Image 35.czi
# Image Number : 60
# Rescaling image. New Image Size:  (77, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (69, 74, 73)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:52: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230208exp_20230322Y_KLF4cy3/Image 14.czi
# Image Number : 61
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (67, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (68, 79, 80)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230208exp_20230322Y_KLF4cy3/Image 13.czi
# Image Number : 62
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (77, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (71, 83, 83)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230208exp_20230322Y_KLF4cy3/Image 15.czi
# Image Number : 63
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (90, 90, 84)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230208exp_20230315Y_KLF4cy3/Image 9.czi
# Image Number : 64
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (77, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (83, 74, 77)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230208exp_20230315Y_KLF4cy3/Image 8.czi
# Image Number : 65
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (105, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (94, 73, 75)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':
# hsc_raw_data/young/wetransfer_28032023/20230208exp_20230315Y_KLF4cy3/Image 7.czi
# Image Number : 66
# WARNING, Skiping image. No Ch1-T2 Channel.
# Rescaling image. New Image Size:  (89, 135, 135)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:320: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img == '':
# (88, 77, 69)
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:223: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# /home/isglobal.lan/pianez/projects/hsc_nucleus/hsc_methods/hsc_spatial_stats.py:249: UserWarning: No contour levels were found within the data range.
#   plt.contour(
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# hsc_raw_data/young/wetransfer-5f111b/20201119expYH3k9me2AF488/Image 16.czi
# Image Number : 166
# WARNING, Skiping image. No Ch1-T2 Channel.
# WARNING, Skiping image. No Ch1-T2 Channel.
# Outlier identified - skipping
# Outlier identified - skipping
# Outlier identified - skipping
# /tmp/ipykernel_403794/901823479.py:58: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if img=='':

# %%
## Segmentation without resizing, keeping original images size intact

#containing folder with .czi images inside
input_dir = 'hsc_raw_data'

conditions = ['old', 'treated_RhoAi', 'treated_NaB', 'compressed_8um',
             'compressed_3um', 'RhoA_KO', 'young', 'compressed_5um']

#containing folder with .czi images inside
outliers = pd.read_csv("hsc_raw_data/czi_image_outliers.csv")['path'].values
output_dir = f'segmented_nucleus/original'

if not os.path.exists(output_dir):
        os.makedirs(output_dir)

for cond in os.listdir(input_dir):
    
    output_dir = f'segmented_nucleus/original/{cond}'
    if not os.path.exists(output_dir):
            os.makedirs(output_dir)

    img_list = glob(f'{input_dir}/{cond}/**/*.czi', recursive=True)

    for i, img_path in enumerate(img_list, 1):

        print("Image Number : "+ str(i))

        out_path = get_output_filename_with_subfolder(
            img_path, output_dir, suffic='XY')

        # If this cell was already processed - skip
        if os.path.exists(out_path):
            continue

        # skip outliers
        if img_path in outliers:
            print('Outlier identified - skipping')
            continue
        
        #DAPI signal usually is named "Ch1-T3" 
        img, nuc_mask = czi_image_preprocessing(
            img_path, output_dir, channel_name='Ch1-T3', resize=False)

        if img=='':
        #if missing then search for "Ch1-T2" channel
            img, nuc_mask = czi_image_preprocessing(
                img_path, output_dir, channel_name='Ch1-T2', resize=False)
                
            if img=='':
                continue

# %% [markdown]
# ***
