# %% [markdown]
# ##### Author: Pablo Iañez Picazo
# ##### Biomedical Data Science lab

# %%
# Load all the necessary libraries
from glob import glob
import numpy as np
import seaborn as sns
import napari

import matplotlib.pyplot as plt
from skimage.io import imread

from methods import seg_utils

# %%
# Set visual properties for plotting
sns.set(rc={"figure.figsize": (6, 4)})
sns.set_style("whitegrid")

# %%
# Set up parameters
res = 0.1
folder = "data/manual_segmentation"
conditions = [
    "young",
    "aged",
    "aged_treated_RhoAi",
]

palette = {
    "Young": (0.00392, 0.45098, 0.69803),
    "Aged": (0.00784, 0.61960, 0.45098),
    "Aged + Ri": (0.8, 0.47058, 0.73725),
}

# %% [markdown]
# Prepare the Napari viewer for manual segmentation:

# %%
viewer = napari.Viewer()

# For each condition
for cond in conditions[2:]:

    # Get a list of image files (CZI format) within the condition directory
    img_list = glob(f"{folder}/{cond}/*.czi", recursive=True)

    # For each image within this condition
    for i, img_path in enumerate(img_list[:1], 1):
        print(img_path)
        im, nuc_mask = seg_utils.czi_image_preprocessing(img_path, res)

        n_ims_out = int(im.shape[0] * 0.2)
        n_down = n_ims_out
        n_up = im.shape[0] - n_ims_out
        print(n_ims_out)

        viewer.add_image(im[n_down:n_up], name=cond)

        # Create an empty labels layer for manual segmentation
        # Initialize with zeros of same shape as image
        manual_labels = np.zeros(im[n_down:n_up].shape, dtype=np.uint16)
        annot_layer = viewer.add_labels(
            manual_labels, name="Manual Segmentation"
        )

        napari.run()
# Out:
# data/manual_segmentation/aged_treated_RhoAi/nuc_2.czi
# (18, 1024, 1024)
# Rescaling image. New Image Size:  (72, 135, 135)
# 14

# %%
# Compute segmentation metrics to assess the quality of manual annotations
metrics_df = seg_utils.calculate_segmentation_metrics_2D(
    conditions, folder, res
)
metrics_df
# Out:
# data/manual_segmentation/young/nuc_2.czi
# (17, 1024, 1024)
# Rescaling image. New Image Size:  (75, 135, 135)
# data/manual_segmentation/young/nuc_1.czi
# (20, 1024, 1024)
# Rescaling image. New Image Size:  (88, 135, 135)
# data/manual_segmentation/young/nuc_3.czi
# (24, 1024, 1024)
# Rescaling image. New Image Size:  (77, 135, 135)
# data/manual_segmentation/aged/nuc_2.czi
# (27, 1024, 1024)
# Rescaling image. New Image Size:  (108, 135, 135)
# data/manual_segmentation/aged/nuc_1.czi
# (19, 1024, 1024)
# Rescaling image. New Image Size:  (84, 135, 135)
# data/manual_segmentation/aged/nuc_3.czi
# (19, 1024, 1024)
# Rescaling image. New Image Size:  (76, 135, 135)
# data/manual_segmentation/aged_treated_RhoAi/nuc_2.czi
# (18, 1024, 1024)
# Rescaling image. New Image Size:  (72, 135, 135)
# data/manual_segmentation/aged_treated_RhoAi/nuc_1.czi
# (21, 1024, 1024)
# Rescaling image. New Image Size:  (84, 135, 135)
# data/manual_segmentation/aged_treated_RhoAi/nuc_3.czi
# (20, 1024, 1024)
# Rescaling image. New Image Size:  (80, 135, 135)
#      Dice Score  Precision    Recall  Jaccard Score  Specificity  Accuracy  \
# 0      0.954545   0.993569  0.918471       0.913043     0.993694  0.954973
# 1      0.976518   0.984808  0.968366       0.954113     0.985211  0.976831
# 2      0.971061   0.993421  0.949686       0.943750     0.993151  0.970492
# 3      0.971501   0.989252  0.954376       0.944581     0.988447  0.970492
# 4      0.972205   0.994105  0.951249       0.945913     0.993311  0.970492
# ..          ...        ...       ...            ...          ...       ...
# 421    0.937087   0.995469  0.885173       0.881621     0.996483  0.944601
# 422    0.913564   0.995729  0.843926       0.840882     0.996830  0.925446
# 423    0.936099   0.983467  0.893085       0.879874     0.989447  0.949671
# 424    0.933098   0.993015  0.880000       0.874586     0.995969  0.950235
# 425    0.935337   0.968860  0.904057       0.878530     0.984861  0.957183
#
#               Condition                                            Nucleus  \
# 0                 young           data/manual_segmentation/young/nuc_2.czi
# 1                 young           data/manual_segmentation/young/nuc_2.czi
# 2                 young           data/manual_segmentation/young/nuc_2.czi
# 3                 young           data/manual_segmentation/young/nuc_2.czi
# 4                 young           data/manual_segmentation/young/nuc_2.czi
# ..                  ...                                                ...
# 421  aged_treated_RhoAi  data/manual_segmentation/aged_treated_RhoAi/nu...
# 422  aged_treated_RhoAi  data/manual_segmentation/aged_treated_RhoAi/nu...
# 423  aged_treated_RhoAi  data/manual_segmentation/aged_treated_RhoAi/nu...
# 424  aged_treated_RhoAi  data/manual_segmentation/aged_treated_RhoAi/nu...
# 425  aged_treated_RhoAi  data/manual_segmentation/aged_treated_RhoAi/nu...
#
#      Slice Index  N slices
# 0             16        49
# 1             17        49
# 2             18        49
# 3             19        49
# 4             20        49
# ..           ...       ...
# 421           50        42
# 422           51        42
# 423           52        42
# 424           53        42
# 425           54        42
#
# [426 rows x 10 columns]

# %%
for m in ["Dice Score", "Precision", "Recall"]:
    print(f"\n{m} Statistics:")
    print(metrics_df[m].mean())
    print(metrics_df[m].std())
# Out:
# Dice Score Statistics:
# 0.9620895335946156
# 0.016638116531991463
#
# Precision Statistics:
# 0.9920796622248462
# 0.007986880476139019
#
# Recall Statistics:
# 0.9345628004600349
# 0.03295185603619241

# %%
metrics_df = seg_utils.update_labels(metrics_df)

# %%
for m in ["Dice Score", "Precision", "Recall"]:

    plt.figure(figsize=(3, 2))
    sns.boxplot(
        data=metrics_df,
        x="Condition",
        y=m,
        palette=palette,
        boxprops=dict(facecolor="none"),
    )
    b = sns.stripplot(
        data=metrics_df,
        x="Condition",
        y=m,
        hue="Condition",
        palette=palette,
        alpha=0.4,
        legend=False,
    )
    b.set_title(m)
    plt.ylim([0.8, 1.0])
    plt.show()
# Out:
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
plt.figure(figsize=(6, 3))
sns.lineplot(
    data=metrics_df,
    x="Slice Index",
    y="Dice Score",
    hue="Condition",
    palette=palette,
)
plt.title("Dice Score by Absolute Slice Index")
plt.xlabel("Slice Index")
plt.ylabel("Dice Score")
plt.legend(title="Condition")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/pianez/miniconda3/envs/hsc/lib/python3.11/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Check in some example slides the overlap of both the automatic
# segmentation using Otsu and the manual annotation
for cond in conditions:
    img_list = glob(f"{folder}/{cond}/*.czi", recursive=True)

    for img_path in img_list[:1]:
        print(img_path)
        annot_path = img_path.replace(".czi", ".tif")

        im, nuc_mask = seg_utils.czi_image_preprocessing(img_path, res)
        im = im * nuc_mask
        manual_annot = imread(annot_path)

        n_down = int(im.shape[0] * 0.2)
        im, nuc_mask, manual_annot = (
            im[35],
            nuc_mask[35],
            manual_annot[35 - n_down],
        )

        ax = seg_utils.plot_masks_contour(im, nuc_mask, manual_annot)
        ax.set_axis_off()
        plt.tight_layout()
        plt.show()
# Out:
# data/manual_segmentation/young/nuc_2.czi
# (17, 1024, 1024)
# Rescaling image. New Image Size:  (75, 135, 135)
# data/manual_segmentation/aged/nuc_2.czi
# (27, 1024, 1024)
# Rescaling image. New Image Size:  (108, 135, 135)
# data/manual_segmentation/aged_treated_RhoAi/nuc_2.czi
# (18, 1024, 1024)
# Rescaling image. New Image Size:  (72, 135, 135)
